# %% [markdown]
# <h1><center>Cars in Russia </center></h1>

# %% [markdown]
# **My data was collected at the end of 2020 from a popular car service in Russia.**
#
# **With this data, we can analyze the machines according to their characteristics. For example, prices and model of a car, mileage of a car, maximum speed of a car, volume of a car, fuel of a car. We can also find out the most expensive car. We can find out the ratio of the price of the car for the year of its production.**

# %% [markdown]
# **Link to data => https://www.kaggle.com/beaver68/cars-dataset-in-russia**

# %%
import pandas as pd

# %%
my_data = pd.read_csv("cars_dataset.csv")
my_data.head(5)
# Out:
#    Unnamed: 0            mark        Box Drive_unit  Seats  Doors Country  \
# 0           0  Mercedes-Benz   automatic       full    5.0    5.0  German
# 1           1  Mercedes-Benz   automatic       full    5.0    5.0  German
# 2           2  Mercedes-Benz   automatic       full    5.0    5.0  German
# 3           3  Mercedes-Benz   automatic       full    5.0    5.0  German
# 4           4  Mercedes-Benz   automatic       full    5.0    5.0  German
#
#      Engine  Volume  Color  ...  Consumption               Engine_Power  \
# 0    diesel     2.9  black  ...          9.8                        NaN
# 1    diesel     2.9  green  ...          9.6                        NaN
# 2  gasoline     4.0  black  ...         12.1  direct injection (direct)
# 3  gasoline     4.0  black  ...         12.1  direct injection (direct)
# 4  gasoline     4.0   gray  ...         12.1  direct injection (direct)
#
#    Restyling Release_start_series End_Serial Trunk_volume_max  \
# ...

# %%
my_data.shape
# Out:
# (22702, 55)

# %% [markdown]
# **Lets see column names**

# %%
copy_data = my_data.copy()
list(copy_data.columns)
# Out:
# ['Unnamed: 0',
#  'mark',
#  'Box',
#  'Drive_unit',
#  'Seats',
#  'Doors',
#  'Country',
#  'Engine',
#  'Volume',
#  'Color',
#  'Mileage',
#  'Price',
#  'Year',
#  'Car_type',
#  'Generation',
#  'Model',
#  'Drive',
#  'Boost_type',
#  'Cylinder_location',
#  'Front_brakes',
#  'Engine_volume',
#  'Width',
#  'Front_Suspension_type',
#  'Diameter_cylinder_and_stroke_piston',
#  'Maximum_power',
#  'Length',
#  'Car_class',
#  'Wheelbase',
#  'Cylinders',
#  'Height',
#  'Fuel',
#  'Torque',
#  'Valves_per_cylinder',
#  'Volume_fuel_tank',
#  'Rear_track_width',
#  'Front_track_width',
#  'Curb_weight_kg',
#  'Clearance',
#  'Engine_Location',
#  'Maximum_speed',
#  'Wheel_size',
#  'Transmissions',
#  'Speed_to_100',
#  'Full_weight',
#  'Compression_ratio',
#  'Consumption',
#  'Engine_Power',
#  'Restyling',
#  'Release_start_series',
#  'End_Serial',
#  'Trunk_volume_max',
#  'Trunk_volume_min',
#  'Expense_city',
#  'Expense_track',
#  'Consumption_average']

# %% [markdown]
# **As we see, I have 56 columns. I decided drop some columns. And work with columns, which more interesting. But, every column is important.**

# %%
data = copy_data[['mark', 'Box', 'Drive_unit', 'Seats', 'Country', 'Engine', 'Volume',
 'Color', 'Mileage', 'Price', 'Year', 'Car_type', 'Model', 'Cylinders', 'Maximum_speed']]
data.head(10)
# Out:
#              mark        Box Drive_unit  Seats Country    Engine  Volume  \
# 0  Mercedes-Benz   automatic       full    5.0  German    diesel     2.9
# 1  Mercedes-Benz   automatic       full    5.0  German    diesel     2.9
# 2  Mercedes-Benz   automatic       full    5.0  German  gasoline     4.0
# 3  Mercedes-Benz   automatic       full    5.0  German  gasoline     4.0
# 4  Mercedes-Benz   automatic       full    5.0  German  gasoline     4.0
# 5  Mercedes-Benz   automatic       full    5.0  German    diesel     2.9
# 6  Mercedes-Benz   automatic       full    5.0  German    diesel     2.9
# 7  Mercedes-Benz   automatic       full    5.0  German    diesel     2.9
# 8  Mercedes-Benz   automatic       full    5.0  German  gasoline     4.0
# 9  Mercedes-Benz   automatic       full    5.0  German    diesel     2.9
#
#    Color  Mileage       Price    Year Car_type     Model  Cylinders  \
# 0  black      0.0  12902800.0  2020.0      SUV  G-Class         6.0
# ...

# %%
data.sample(10)
# Out:
#               mark        Box Drive_unit  Seats      Country    Engine  \
# 20462      Toyota   automatic       full    7.0        Japan  gasoline
# 5809        Honda    variator      front    5.0        Japan  gasoline
# 6147      Hyundai   automatic      front    5.0  South Korea  gasoline
# 14921     Citroen   automatic      front    5.0       France  gasoline
# 4457   Volkswagen   automatic      front    7.0       German    diesel
# 4253   Volkswagen   automatic       full    5.0       German  gasoline
# 11396     Peugeot   mechanics      front    5.0       France    diesel
# 13321  Mitsubishi   automatic       full    5.0        Japan  gasoline
# 13264    Chrysler   automatic      front    7.0          USA  gasoline
# 454        Nissan   mechanics       full    5.0        Japan  gasoline
#
#        Volume   Color   Mileage      Price    Year     Car_type  \
# 20462     3.0   black  316650.0   870000.0  2002.0      Minivan
# ...

# %%
# check for NaN objects
data.isnull().sum()
# Out:
# mark             0
# Box              0
# Drive_unit       0
# Seats            0
# Country          0
# Engine           0
# Volume           0
# Color            0
# Mileage          0
# Price            0
# Year             0
# Car_type         0
# Model            0
# Cylinders        0
# Maximum_speed    0
# dtype: int64

# %%
# Show mark names
data['mark'].drop_duplicates().to_list()
# Out:
# ['Mercedes-Benz ',
#  'Mitsubishi ',
#  'Audi ',
#  'Volkswagen ',
#  'Jaguar ',
#  'Nissan ',
#  'Infiniti ',
#  'Skoda ',
#  'Haval ',
#  'Renault ',
#  'LADA (VAZ) ',
#  'Jeep ',
#  'Volvo ',
#  'BMW ',
#  'Toyota ',
#  'Land Rover ',
#  'MINI ',
#  'Hyundai ',
#  'YAZ ',
#  'Suzuki ',
#  'Citroen ',
#  'Peugeot ',
#  'Changan ',
#  'Chevrolet ',
#  'Bentley ',
#  'Cadillac ',
#  'Lamborghini ',
#  'Kia ',
#  'Rolls-Royce ',
#  'Lexus ',
#  'Subaru ',
#  'Dodge ',
#  'Porsche ',
#  'Genesis ',
#  'Honda ',
#  'Lincoln ',
#  'Mazda ',
#  'Ford ',
#  'Geely ',
#  'Opel ',
#  'Smart ',
#  'AC ',
#  'Chery ',
#  'Tesla ',
#  'TagAZ ',
#  'Great Wall ',
#  'SsangYong ',
#  'GAZ ',
#  'SEAT ',
#  'Fiat ',
#  'Datsun ',
#  'Acura ',
#  'Daewoo ',
#  'Ravon ',
#  'Isuzu ',
#  'Lifan ',
#  'Chrysler ',
#  'Ferrari ',
#  'Luxgen ',
#  'Vortex ',
#  'Moskvich ',
#  'Daihatsu ',
#  'Saab ',
#  'DongFeng ',
#  'ZAZ ',
#  'Alfa Romeo ',
#  'Iran Khodro ',
#  'GMC ',
#  'Maserati ',
# ...

# %% [markdown]
# **Lets look at how many cars there were for each brand**

# %%
data.mark.value_counts()
# Out:
# Mercedes-Benz     1950
# BMW               1526
# Toyota            1212
# Kia               1121
# Volkswagen        1097
#                   ...
# Race car             3
# McLaren              2
# ZIL                  2
# Scion                2
# AMC                  2
# Name: mark, Length: 85, dtype: int64

# %% [markdown]
# **Lets see how much revenue each brand**

# %%
# I find max and min price each car marks
data.loc[data.Price.notnull()].groupby('mark').Price.agg([sum, min, max ,'count'])
# Out:
#                        sum         min         max  count
# mark
# AC              35900000.0   6950000.0  11000000.0      4
# AMC              2800000.0   1300000.0   1500000.0      2
# Acura           62446980.0    500000.0   3100000.0     47
# Alfa Romeo      15242333.0    399000.0   1450000.0     20
# Aston Martin   102380000.0   5000000.0  17890000.0      8
# ...                    ...         ...         ...    ...
# Vortex           6576000.0    115000.0    350000.0     30
# YAZ             74231999.0     35000.0   2500000.0    146
# ZAZ             19942137.0     30000.0   1550000.0     65
# ZIL             23000000.0  11000000.0  12000000.0      2
# ZX                920000.0    230000.0    230000.0      4
#
# [85 rows x 4 columns]

# %% [markdown]
# **Let's look at 'Maserati' only**

# %%
data.loc[data.mark == 'Maserati '].sort_values(['Year','Model'],ascending=False)
# Out:
#             mark        Box Drive_unit  Seats Country    Engine  Volume  \
# 17624  Maserati   automatic       full    5.0   Italy  gasoline     3.0
# 17629  Maserati   automatic       full    5.0   Italy    diesel     3.0
# 17824  Maserati   automatic       full    5.0   Italy  gasoline     3.0
# 17830  Maserati   automatic       full    5.0   Italy    diesel     3.0
# 22439  Maserati   automatic       full    5.0   Italy  gasoline     3.0
# 22443  Maserati   automatic       rear    5.0   Italy    diesel     3.0
# 17623  Maserati   automatic       full    5.0   Italy    diesel     3.0
# 17827  Maserati   automatic       full    5.0   Italy    diesel     3.0
# 17620  Maserati   automatic       full    5.0   Italy    diesel     3.0
# 17621  Maserati   automatic       full    5.0   Italy  gasoline     3.0
# 17626  Maserati   automatic       full    5.0   Italy  gasoline     3.0
# 17823  Maserati   automatic       full    5.0   Italy    diesel     3.0
# ...

# %% [markdown]
# **Some cars that were made afer 2014**

# %%
data.loc[data.Year > 2014].sort_values(by='Year')
# Out:
#                 mark        Box Drive_unit  Seats      Country    Engine  \
# 5278           Audi       robot      front    5.0       German  gasoline
# 5884     Mitsubishi   automatic       full    5.0        Japan  gasoline
# 5875     Mitsubishi    variator      front    5.0        Japan  gasoline
# 5795        Hyundai   automatic      front    5.0  South Korea  gasoline
# 5793        Hyundai   automatic      front    5.0  South Korea  gasoline
# ...              ...        ...        ...    ...          ...       ...
# 725   Mercedes-Benz       robot       full    5.0       German  gasoline
# 723   Mercedes-Benz       robot       full    5.0       German  gasoline
# 719          Toyota    variator      front    5.0        Japan  gasoline
# 717          Toyota   automatic       full    5.0        Japan  gasoline
# 0     Mercedes-Benz   automatic       full    5.0       German    diesel
#
#       Volume   Color   Mileage       Price    Year  Car_type       Model  \
# ...

# %% [markdown]
# **Some cars that run on hybrid (gasoline, diesel), and sorting by Price**

# %%
data_hybrid_car = data.groupby('Engine').get_group('hybrid')
data_hybrid_car.sort_values(by='Price', ascending=False)
# Out:
#            mark        Box Drive_unit  Seats Country  Engine  Volume  Color  \
# 19229    Lexus    variator       full    4.0   Japan  hybrid     2.5  black
# 19052    Lexus    variator       full    4.0   Japan  hybrid     2.5  black
# 19230    Lexus    variator       full    4.0   Japan  hybrid     2.5  black
# 19053    Lexus    variator       full    4.0   Japan  hybrid     2.5  black
# 7032   Porsche   automatic       full    5.0  German  hybrid     3.0   gray
# ...         ...        ...        ...    ...     ...     ...     ...    ...
# 15645   Toyota   automatic      front    5.0   Japan  hybrid     1.5   gray
# 15644   Toyota   automatic      front    5.0   Japan  hybrid     1.5   gray
# 16722   Toyota   automatic      front    5.0   Japan  hybrid     1.5   gray
# 16721   Toyota   automatic      front    5.0   Japan  hybrid     1.5  green
# 15643   Toyota   automatic      front    5.0   Japan  hybrid     1.5  green
#
# ...

# %% [markdown]
# **Lets take Subaru model 'Forester', and show its 'Price', 'Mileage', 'Year', 'Engine', 'Color'**

# %%
data_Subaru = data.loc[(data.mark == 'Subaru ') & (data.Model=='Forester '), ['Price', 'Mileage', 'Year', 'Engine', 'Color']]
data_Subaru
# Out:
#            Price   Mileage    Year    Engine   Color
# 2172   1300000.0  130000.0  2014.0  gasoline    gray
# 2173   1180273.0   62801.0  2014.0  gasoline   white
# 2174    970000.0  128000.0  2014.0  gasoline   white
# 2175    999000.0  211898.0  2013.0  gasoline  silver
# 2176   1265000.0   49950.0  2014.0  gasoline  silver
# ...          ...       ...     ...       ...     ...
# 22468   580000.0  235000.0  2005.0  gasoline   black
# 22469   650000.0  120000.0  2004.0  gasoline   white
# 22470   355000.0  233388.0  2003.0  gasoline  silver
# 22471   360000.0  222000.0  2003.0  gasoline  silver
# 22472   440000.0  264000.0  2004.0  gasoline   black
#
# [136 rows x 5 columns]

# %%
data_Subaru_ = data.loc[(data.mark == 'Subaru ') & (data.Model=='Forester ')]
data_Subaru_ = data_Subaru_[['mark', 'Model']]
data_Subaru_
# Out:
#           mark      Model
# 2172   Subaru   Forester
# 2173   Subaru   Forester
# 2174   Subaru   Forester
# 2175   Subaru   Forester
# 2176   Subaru   Forester
# ...        ...        ...
# 22468  Subaru   Forester
# 22469  Subaru   Forester
# 22470  Subaru   Forester
# 22471  Subaru   Forester
# 22472  Subaru   Forester
#
# [136 rows x 2 columns]

# %% [markdown]
# **Concat two dataframe**

# %%
data_Subaru_r = pd.concat([data_Subaru_, data_Subaru], axis=1)
data_Subaru_r.sort_values(by='Price', ascending=True)
# Out:
#           mark      Model      Price   Mileage    Year    Engine  Color
# 14324  Subaru   Forester    180000.0  180000.0  1997.0  gasoline  green
# 14328  Subaru   Forester    200000.0  398000.0  1999.0  gasoline  white
# 4338   Subaru   Forester    210000.0  244000.0  2001.0  gasoline  black
# 14325  Subaru   Forester    210000.0  407000.0  1998.0  gasoline  green
# 14330  Subaru   Forester    219000.0  300000.0  1998.0  gasoline  white
# ...        ...        ...        ...       ...     ...       ...    ...
# 10731  Subaru   Forester   2968900.0       0.0  2020.0  gasoline   blue
# 10457  Subaru   Forester   3059900.0       0.0  2020.0  gasoline   gray
# 10726  Subaru   Forester   3059900.0       0.0  2020.0  gasoline   gray
# 10460  Subaru   Forester   3068900.0       0.0  2020.0  gasoline  white
# 10730  Subaru   Forester   3068900.0       0.0  2020.0  gasoline  white
#
# [136 rows x 7 columns]

# %% [markdown]
# **Max and min Price car**

# %%
data.groupby('Price').get_group(data['Price'].max())
# Out:
#            mark        Box Drive_unit  Seats Country    Engine  Volume  Color  \
# 17713  Maybach   automatic       rear    4.0  German  gasoline     6.0  white
# 17883  Maybach   automatic       rear    4.0  German  gasoline     6.0  white
#
#        Mileage        Price    Year Car_type Model  Cylinders  Maximum_speed
# 17713   1724.0  130000000.0  2009.0    Sedan   62        12.0          250.0
# 17883   1724.0  130000000.0  2009.0    Sedan   62        12.0          250.0

# %%
data.groupby('Price').get_group(data['Price'].min())
# Out:
#          mark        Box Drive_unit  Seats Country    Engine  Volume Color  \
# 22506  Mazda   mechanics      front    5.0   Japan  gasoline     2.0  gray
#
#         Mileage    Price    Year   Car_type Model  Cylinders  Maximum_speed
# 22506  300000.0  20000.0  1992.0  Hatchback  626         4.0          200.0

# %% [markdown]
# **Lets see Mileage of Toyota (max, min, mean)**

# %%
Mileage_data_Toyota = data.groupby('mark').get_group('Toyota ')
Mileage_data_Toyota
# Out:
#           mark        Box Drive_unit  Seats Country    Engine  Volume  Color  \
# 706    Toyota    variator       full    5.0   Japan  gasoline     2.0  black
# 707    Toyota    variator       full    5.0   Japan  gasoline     2.0  white
# 708    Toyota   mechanics      front    5.0   Japan  gasoline     2.0  brown
# 709    Toyota    variator       full    5.0   Japan  gasoline     2.0  white
# 710    Toyota    variator       full    5.0   Japan  gasoline     2.0  green
# ...        ...        ...        ...    ...     ...       ...     ...    ...
# 22549  Toyota   automatic       rear    5.0   Japan  gasoline     2.0   gold
# 22550  Toyota   automatic       rear    5.0   Japan  gasoline     2.0  white
# 22551  Toyota   automatic       rear    5.0   Japan  gasoline     2.5   blue
# 22622  Toyota   mechanics      front    5.0   Japan  gasoline     1.6  green
# 22623  Toyota   mechanics      front    5.0   Japan    diesel     2.0  black
#
# ...

# %%
print('max Mileage = ', Mileage_data_Toyota.Mileage.max())
print('min Mileage = ',Mileage_data_Toyota.Mileage.min())
print('mean Mileage = ',Mileage_data_Toyota.Mileage.mean())
# Out:
# max Mileage =  1000000.0
# min Mileage =  0.0
# mean Mileage =  184558.47524752477

# %% [markdown]
# ## Visualization

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
sns.set(style='whitegrid')

# %% [markdown]
# **Lets use last data (Toyota)**

# %%
plt.rcParams["figure.figsize"] = (20,10)
fig = plt.figure()
ax1 = fig.add_subplot()
ax1.set_ylabel('Mileage')
ax1.set_xlabel('Price')
ax1.set_title('Mileage vs. Price of Toyota')
ax1.scatter(Mileage_data_Toyota.Price, Mileage_data_Toyota.Mileage)

# %% [markdown]
# **Visualization by Cylinders in car**

# %%
sns.countplot(data['Cylinders'])
plt.title('Number of Cylinders')
# Out:
# c:\python for sdu\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Number of Cylinders')

# %% [markdown]
# **Plot by seats in every car**

# %%
sns.countplot(data['Seats'], color='green')
plt.title('Seats in car')
# Out:
# c:\python for sdu\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Seats in car')

# %% [markdown]
# **Counting car marks, and ploting**

# %%
mark = pd.DataFrame(data['mark'])
mark_by_count = mark.groupby(['mark']).size().reset_index(name='Count')
mark_by_count
# Out:
#              mark  Count
# 0             AC       4
# 1            AMC       2
# 2          Acura      47
# 3     Alfa Romeo      20
# 4   Aston Martin       8
# ..            ...    ...
# 80        Vortex      30
# 81           YAZ     146
# 82           ZAZ      65
# 83            ZIL      2
# 84            ZX       4
#
# [85 rows x 2 columns]

# %%
plt.figure(figsize=(15,10))
mark_by_count = mark_by_count.sort_values(by='Count',ascending=False)
sns.barplot(x=mark_by_count.mark[:35],y=mark_by_count.Count[:35])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Counting by Country**

# %%
Country_ = pd.DataFrame(data['Country'])
Country_by_count = Country_.groupby(['Country']).size().reset_index(name='Count')
Country_by_count
# Out:
#            Country  Count
# 0                -      2
# 1            China    517
# 2   Czech Republic    506
# 3           France   1595
# 4           German   6536
# 5             Iran     15
# 6            Italy    165
# 7            Japan   5396
# 8           Russia   1542
# 9      South Korea   2294
# 10           Spain     41
# 11          Sweden    493
# 12          Taiwan     13
# 13              UK   1045
# 14             USA   2356
# 15         Ukraine    106
# 16      Uzbekistan     80

# %%
plt.figure(figsize=(15,10))
Country_by_count = Country_by_count.sort_values(by='Count',ascending=False)
sns.barplot(x=Country_by_count.Country[:35],y=Country_by_count.Count[:35])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Ploting Dodge car price by model**

# %%
data_Dodge = data.groupby('mark').get_group('Dodge ').reset_index(drop=True)
data_Dodge
# Out:
#        mark        Box Drive_unit  Seats Country    Engine  Volume  \
# 0    Dodge   automatic       rear    5.0     USA  gasoline     5.7
# 1    Dodge   automatic       rear    5.0     USA  gasoline     3.6
# 2    Dodge   automatic       rear    5.0     USA  gasoline     5.7
# 3    Dodge   automatic       rear    5.0     USA  gasoline     3.6
# 4    Dodge   automatic       rear    5.0     USA  gasoline     5.7
# ..      ...        ...        ...    ...     ...       ...     ...
# 200  Dodge   automatic       full    6.0     USA  gasoline     5.7
# 201  Dodge   automatic       full    6.0     USA    diesel     6.7
# 202  Dodge   automatic       full    6.0     USA  gasoline     5.7
# 203  Dodge   automatic       full    6.0     USA  gasoline     5.7
# 204  Dodge   automatic       full    6.0     USA  gasoline     5.7
#
#           Color   Mileage      Price    Year Car_type        Model  Cylinders  \
# 0        orange   40000.0  3650000.0  2017.0    Sedan     Charger         8.0
# ...

# %%
plt.rcParams["figure.figsize"] = (20,10)
plt.scatter(x=data_Dodge['Model'], y=data_Dodge['Price'])
plt.title('Price x Model Dodge car')
plt.xlabel('Model')
plt.ylabel('Price')
plt.plot()
# Out:
# []

# %% [markdown]
# **Cylinders my marks**

# %%
pd.crosstab(data["mark"],data["Cylinders"]).head(10).plot(kind="bar", stacked=True)
plt.show()
